# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(3,4)

# %%
plt.plot(3,4,'^') #Markers: o, s, p, ^, .....

# %%
plt.plot(3,4,'ro')
plt.show()
plt.plot(2,4.2,'b^')
plt.show()

# %%
plt.plot(3,4,'ro', label='Red Circle')
# plt.show()
plt.plot(2,4.2,'b^', label='Blue Triangle')
plt.legend()
plt.show()

# %%
x = [0,1]
y = [0,2]

plt.plot(x,y,'b^--') #Color Point Line-> -, --, :, ......

# %%
import numpy as np

# %%
x = np.linspace(0, 3*np.pi, 101)
y = np.sin(x)

plt.plot(x,y, 'm--')

# %% [markdown]
# ## Exercise !

# %%
# Draw letter X
x = [0,1]
y = [0,1]
# Out:
# (-0.05, 1.05, -0.05, 1.05)

# %%
plt.plot([0,1], [0,1], 'm')
plt.plot([0,1], [1,0], 'm')
plt.axis('square')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot([0,1], [0,1], 'm')
#       2 plt.plot([0,1], [1,0], 'm')
#       3 plt.axis('square')
#
# NameError: name 'plt' is not defined
